# %%
import numpy as np
import pickle
# VISUALISE 2D NUMPY
asd = pickle.load(open('./pitch/p360/p360_001_mic1.pkl','rb'))
x_org_1 = np.load('./spmel/p360/p360_001_mic1.npy', 'r')
x_org_1

x_org_1 = np.rot90(x_org_1)

from matplotlib import pyplot as plt

plt.imshow(x_org_1, cmap='gray')
plt.show()

# %%
x_org_1 = np.load(asd[0])
x_org_1

x_org_1 = np.rot90(x_org_1)

from matplotlib import pyplot as plt

plt.imshow(x_org_1, cmap='gray')
plt.show()

# %%
# PLOT VECTOR
import numpy as np
tester = np.load('./pitch/p259_203_mic1..npy')
tester = np.rot90(tester)
from matplotlib import pyplot as plt

plt.imshow(tester, cmap='gray')
plt.show()

# %%
# LISTEN TO AUDIO FILE
import os
from IPython.display import Audio
import soundfile as sf

song_for_play = '/import/c4dm-datasets/VCTK-Corpus-0.92/wav48_silence_trimmed/p225/p225_001_mic1.flac'
audio_for_play, sr_for_play = sf.read(song_for_play)
Audio(data=audio_for_play, rate=sr_for_play, autoplay=True)
